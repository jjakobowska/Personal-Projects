# %%
#recognition of handwriting using scikit learn

# %%
from sklearn import datasets
 
digits = datasets.load_digits()

#attributes
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
#shows the digits
import matplotlib.pyplot as plt
# %matplotlib inline

nplot = 10
fig, ax = plt.subplots(2,5, figsize=(10,10))
ax = ax.ravel()

for n in range(nplot):
    ax[n].imshow(digits.images[n])

plt.show()

# %%
y = digits.target
x = digits.images.reshape((len(digits.images), -1))


x.shape


#now we have every iamge represented in single dimension
# Out:
# (1797, 64)

# %%
#splitting the data into training set and valdation set
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, shuffle=True, train_size = 0.7, test_size=0.3)

x_test.shape
# Out:
# (540, 64)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(20),
                    activation='logistic',
                    alpha=1e-4, 
                    solver='sgd',
                    tol=1e-4, 
                    random_state=1,
                    learning_rate_init=.1,
                    verbose=True)

# %%
mlp.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 2.13280286
# Iteration 2, loss = 1.60179914
# Iteration 3, loss = 1.13346012
# Iteration 4, loss = 0.76545645
# Iteration 5, loss = 0.53545973
# Iteration 6, loss = 0.39269016
# Iteration 7, loss = 0.30264072
# Iteration 8, loss = 0.25448833
# Iteration 9, loss = 0.20826549
# Iteration 10, loss = 0.18091916
# Iteration 11, loss = 0.16008808
# Iteration 12, loss = 0.14894767
# Iteration 13, loss = 0.13478278
# Iteration 14, loss = 0.12806960
# Iteration 15, loss = 0.11323099
# Iteration 16, loss = 0.10879287
# Iteration 17, loss = 0.10034792
# Iteration 18, loss = 0.09326764
# Iteration 19, loss = 0.08594519
# Iteration 20, loss = 0.08688702
# Iteration 21, loss = 0.08138321
# Iteration 22, loss = 0.07353767
# Iteration 23, loss = 0.06979582
# Iteration 24, loss = 0.06744882
# Iteration 25, loss = 0.06432794
# Iteration 26, loss = 0.06120610
# Iteration 27, loss = 0.05902110
# Iteration 28, loss = 0.05653516
# Iteration 29, loss = 0.05375205
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(mlp.loss_curve_, 'o-')

# %%
mlp.predict(x_
